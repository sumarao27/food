# %%
import pandas as pd
import numpy as np
import nltk
import sqlite3
from tkinter import *

# %%
import os

csv_file_path=os.path.join("food_reviews.csv")
df=pd.read_csv(csv_file_path)

df.head()
# Out:
#   food_item                    review sentiment
# 0     Pizza      Very tasty and fresh  positive
# 1    Burger         Too oily and cold  negative
# 2     Pasta             Average taste   neutral
# 3   Biryani  Very delicious and spicy  positive
# 4      Dosa          Crispy and tasty  positive

# %%
df.shape
# Out:
# (30, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   food_item  30 non-null     object
#  1   review     30 non-null     object
#  2   sentiment  30 non-null     object
# dtypes: object(3)
# memory usage: 852.0+ bytes

# %%
df.isnull().sum()
# Out:
# food_item    0
# review       0
# sentiment    0
# dtype: int64

# %%
# Step 3: Classify the user

user = input("Enter user type (owner/customer): ")

print("User type is:", user)
# Out:
# Enter user type (owner/customer): owner
# User type is: owner

# %%
# Step 4: Collect food review from user

food_item = input("Enter food item: ")

review = input("Enter your review about the food: ")

print("Food Item:", food_item)
print("Review:", review)
# Out:
# Enter food item: 1
# Enter your review about the food: 5
# Food Item: 1
# Review: 5

# %%
df.columns
# Out:
# Index(['food_item', 'review', 'sentiment'], dtype='object')

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    16
# negative     9
# neutral      5
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['sentiment'].value_counts().plot(kind='bar')

plt.title("Sentiment Analysis of Food Reviews")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")

plt.show()

# %%
owner_code = "1234"

user_code = input("Enter verification code: ")

if user_code == owner_code:
    print("Ownership verified")
else:
    print("Access denied")
# Out:
# Enter verification code: 1256
# Access denied

# %%
print("Choose an option:")
print("1. Popup")
print("2. Root folder")
print("3. View data")

choice = input("Enter your choice: ")

if choice == "1":
    print("Popup message displayed")

elif choice == "2":
    print("Opening root folder")

elif choice == "3":
    print(df)

else:
    print("Invalid option")
# Out:
# Choose an option:
# 1. Popup
# 2. Root folder
# 3. View data
# Enter your choice: 2
# Opening root folder

# %%
# View all data
print(df)
# Out:
#      food_item                    review sentiment
# 0        Pizza      Very tasty and fresh  positive
# 1       Burger         Too oily and cold  negative
# 2        Pasta             Average taste   neutral
# 3      Biryani  Very delicious and spicy  positive
# 4         Dosa          Crispy and tasty  positive
# 5         Idli                   Too dry  negative
# 6   Fried Rice               Good flavor  positive
# 7      Noodles       Not cooked properly  negative
# 8     Sandwich                Okay taste   neutral
# 9    Ice Cream     Very sweet and creamy  positive
# 10        Cake        Soft and delicious  positive
# 11      Coffee              Bitter taste  negative
# 12         Tea                Good aroma  positive
# 13       Salad          Fresh vegetables  positive
# 14        Soup                 Too salty  negative
# 15       Pizza        Cheese was amazing  positive
# 16      Burger                 Not fresh  negative
# 17       Pasta              Normal taste   neutral
# 18     Biryani            Very flavorful  positive
# 19        Dosa                  Too oily  negative
# 20        Idli             Soft and good  positive
# 21  Fried Rice             Average taste   neutral
# 22     Noodles                Very tasty  positive
# 23    Sandwich                   Too dry  negative
# 24   Ice Cream        Good but too sweet   neutral
# 25        Cake      Very fresh and tasty  positive
# 26      Coffee             Perfect taste  positive
# 27         Tea                Too strong  negative
# 28       Salad         Healthy and fresh  positive
# 29        Soup                Good taste  positive

# %%
df.groupby('food_item')['sentiment'].value_counts()
# Out:
# food_item   sentiment
# Biryani     positive     2
# Burger      negative     2
# Cake        positive     2
# Coffee      negative     1
#             positive     1
# Dosa        negative     1
#             positive     1
# Fried Rice  neutral      1
#             positive     1
# Ice Cream   neutral      1
#             positive     1
# Idli        negative     1
#             positive     1
# Noodles     negative     1
#             positive     1
# Pasta       neutral      2
# Pizza       positive     2
# Salad       positive     2
# Sandwich    negative     1
#             neutral      1
# Soup        negative     1
#             positive     1
# Tea         negative     1
#             positive     1
# Name: count, dtype: int64

# %%
df = df.drop_duplicates()
df = df.dropna()

print("Cleaned Data:")
print(df)
# Out:
# Cleaned Data:
#      food_item                    review sentiment
# 0        Pizza      Very tasty and fresh  positive
# 1       Burger         Too oily and cold  negative
# 2        Pasta             Average taste   neutral
# 3      Biryani  Very delicious and spicy  positive
# 4         Dosa          Crispy and tasty  positive
# 5         Idli                   Too dry  negative
# 6   Fried Rice               Good flavor  positive
# 7      Noodles       Not cooked properly  negative
# 8     Sandwich                Okay taste   neutral
# 9    Ice Cream     Very sweet and creamy  positive
# 10        Cake        Soft and delicious  positive
# 11      Coffee              Bitter taste  negative
# 12         Tea                Good aroma  positive
# 13       Salad          Fresh vegetables  positive
# 14        Soup                 Too salty  negative
# 15       Pizza        Cheese was amazing  positive
# 16      Burger                 Not fresh  negative
# 17       Pasta              Normal taste   neutral
# 18     Biryani            Very flavorful  positive
# 19        Dosa                  Too oily  negative
# 20        Idli             Soft and good  positive
# 21  Fried Rice             Average taste   neutral
# 22     Noodles                Very tasty  positive
# 23    Sandwich                   Too dry  negative
# 24   Ice Cream        Good but too sweet   neutral
# 25        Cake      Very fresh and tasty  positive
# 26      Coffee             Perfect taste  positive
# 27         Tea                Too strong  negative
# 28       Salad         Healthy and fresh  positive
# 29        Soup                Good taste  positive
